# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.cm as cm
from sys import stdout
# %matplotlib notebook
plt.rcParams['figure.figsize'] = [6, 4]
plt.rcParams['figure.dpi'] = 200

# %%
def plotcircles():
    for i in range(len(radii)):
        cc = plt.Circle((centres[i].real,centres[i].imag), radii[i] ,fill=False, color=np.random.rand(3,),lw=1)
        ax.add_artist( cc )
        #plt.text(centres[i].real,centres[i].imag,k[i],size='xx-small')
        #ax.annotate(i,xy=(centres[i].real,centres[i].imag))

# %%
from itertools import combinations
def nextcircle(k1,z1,k2,z2,k3,z3,n):
    if n>=10:
        return
    
    global centres,radii,k
    
    if len(radii)>=100000:
        return
    k4_1=k1+k2+k3+2*np.sqrt(k1*k2+k2*k3+k3*k1)
    k4_2=k1+k2+k3-2*np.sqrt(k1*k2+k2*k3+k3*k1)
    z4_1=(z1*k1+z2*k2+z3*k3+2*np.sqrt(k1*z1*k2*z2+k2*z2*k3*z3+k3*z3*k1*z1))/k4_1
    z4_2=(z1*k1+z2*k2+z3*k3-2*np.sqrt(k1*z1*k2*z2+k2*z2*k3*z3+k3*z3*k1*z1))/k4_2
    
    if abs(z4_1)>1 or abs(z4_2)>1:
        z4_1=z4_1*k4_1/k4_2
        z4_2=z4_2*k4_2/k4_1
        temp=k4_1
        k4_1=k4_2
        k4_2=temp 
    kz=[(k1,z1),(k2,z2),(k3,z3)]
    
    z4_1dist=np.absolute(centres-z4_1)
    z4_2dist=np.absolute(centres-z4_2)
    """
    if len(radii)==72:
        print(kz,k4_1,k4_2,z4_1,z4_2)
        print(np.min(z4_1dist[1:]-radii[1:]))"""
        
    if np.min(z4_1dist)>10**(-8) and np.min(z4_2dist)>10**(-8) and len(radii)>=10:
        z4_1=z4_1*k4_1/k4_2
        z4_2=z4_2*k4_2/k4_1
        temp=k4_1
        k4_1=k4_2
        k4_2=temp
        z4_1dist=np.absolute(centres-z4_1)
        z4_2dist=np.absolute(centres-z4_2)
        
    """if np.min([1/k4_1,1/k4_2])<10**(-8):
        return"""
    
    if np.min(z4_1dist)>10**(-8):
        radii=np.append(radii,1/k4_1)
        k=np.append(k,k4_1)
        centres=np.append(centres,z4_1)
        for kz1,kz2 in combinations(kz,2):
            nextcircle(*kz1,*kz2,k4_1,z4_1,n+1)
    

    #z4_2dist=np.absolute(centres-z4_2)
    if np.min(z4_2dist)>10**(-8):
        radii=np.append(radii,1/k4_2)
        k=np.append(k,k4_2)
        centres=np.append(centres,z4_2)
        for kz1,kz2 in combinations(kz,2):
            nextcircle(*kz1,*kz2,k4_2,z4_2,n+1)
    
    stdout.write("\r level: {} circles: {}".format(n,len(radii)))
    stdout.flush()

# %%
r1=1
k1=-1
z1=0+0j
r2=np.random.rand()
r2=0.5
k2=1/r2
z2=(1-r2)+0j
r3=1-r2
k3=1/r3
z3=(-1+r3)+0j
radii=np.array([])
centres=np.array([])
radii=np.append(radii,[r1,r2,r3])
centres=np.append(centres,[z1,z2,z3])
k=1/radii
k[0]=-1.0

# %%
n=0
nextcircle(k1,z1,k2,z2,k3,z3,n)
# Out:
#  level: 9 circles: 3012
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  level: 8 circles: 8502
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#  level: 8 circles: 14002
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# ...

# %%
fig, ax = plt.subplots()
ax.grid(False)
#ax.set_rticks([])

ax.set_aspect(1)

ax.set_xlim([-1,1])
ax.set_ylim([-1,1])
plotcircles()
#cc = plt.Circle(( 0 , 0 ), 1 ,fill=False,color='k')
#ax.add_artist( cc )
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
radii[:10],centres[:10],k[:10]
# Out:
# (array([1.        , 0.5       , 0.5       , 0.33333333, 0.16666667,
#         0.09090909, 0.05555556, 0.03703704, 0.02631579, 0.01960784]),
#  array([ 0.        +0.j        ,  0.5       +0.j        ,
#         -0.5       +0.j        ,  0.        +0.66666667j,
#          0.5       +0.66666667j,  0.72727273+0.54545455j,
#          0.83333333+0.44444444j,  0.88888889+0.37037037j,
#          0.92105263+0.31578947j,  0.94117647+0.2745098j ]),
#  array([-1.,  2.,  2.,  3.,  6., 11., 18., 27., 38., 51.]))

# %%
np.sum(radii[1:]**2)
# Out:
# 0.9951224669526066

# %%
np.max(np.absolute(centres))
# Out:
# 0.999908650771901

# %%
np.min(radii)
# Out:
# 1.5443776930086022e-05

# %%
print(radii.dtype)
# Out:
# float64

# %%
len(radii)
# Out:
# 65537

# %%
plt.figure()
area=[]
for i in range(1,len(radii)):
    area.append(np.sum(radii[:i]**2))
plt.plot(range(1,len(radii)),area,'o')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
unique, counts = np.unique(k, return_counts=True)
plt.figure()
plt.plot(unique,counts,'o')
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
plt.figure()
plt.plot(range(len(radii)),radii)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
radii[:10]
# Out:
# array([1.        , 0.5       , 0.5       , 0.33333333, 0.16666667,
#        0.09090909, 0.05555556, 0.03703704, 0.02631579, 0.01960784])

# %%
len(radii)
# Out:
# 53717

# %%
with open('gasket{}.npz'.format(n),"wb+") as file:
        np.savez_compressed(file,radii=radii,centres=centres)

# %%
hist,bin_edges=np.histogram(radii,bins=100,range=(0,1))
rs=(bin_edges[1:]+bin_edges[:-1])/2
Nr=[]
for r in rs:
    N=0
    for rad in radii:
        if rad>r:
            N=N+1
    Nr.append(N)

# %%
plt.figure()
#plt.plot(rs,Nr)
plt.plot(rs),np.log10(Nr),marker='o')
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
print(mindist[-100:])
# Out:
# [9.64941514019635e-05, 8.240904893340811e-05, 9.133163668379463e-05, 8.373407652206282e-05, 8.240904893340811e-05, 0.0001967275593028549, 0.00011349585031225288, 0.00013692839097563425, 0.00011548175789397859, 0.00011349585031225288, 9.274564172122705e-05, 0.00010705888360320768, 9.582165194756603e-05, 9.274564172122705e-05, 8.058249445200187e-05, 8.956530417557564e-05, 8.184236844083579e-05, 8.058249445200187e-05, 0.00042182954847148744, 5.551115123125783e-17, 0.0001689450736111358, 5.551115123125783e-17, 0.00021730571590727454, 0.00017030752524161707, 0.0001689450736111358, 9.418621989349796e-05, 0.00010574159134001183, 9.902130623677219e-05, 9.418621989349796e-05, 8.939430425491745e-05, 9.911981697680763e-05, 9.327353644486306e-05, 8.939430425491745e-05, 0.00017055438652939183, 0.00010474585771019131, 0.00012857214898358144, 0.00010653384761752881, 0.00010474585771019131, 7.740256996503693e-05, 8.877834770580045e-05, 8.049771410965383e-05, 7.740256996503693e-05, 6.80646218913892e-
# ...

# %%
data=np.log10(radii[radii>0])
#data=data[data>-np.inf]
plt.figure()
fgsdfgh=plt.hist(data,bins=100)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
plt.figure()
sdfg=plt.hist2d(centres.real,centres.imag,bins=1000)
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
from scipy.spatial import Voronoi, voronoi_plot_2d
vor = Voronoi(np.stack((centres.real,centres.imag)).T)
fig = voronoi_plot_2d(vor,line_width=0.25)
plt.show()
print(centres)
# Out:
# <img src="data:image/png;base64,..." width="1200">
# [ 0.        +0.j          0.5       +0.j         -0.5       +0.j
#  ... -0.05071154-0.31904224j -0.05075144-0.31893219j
#  -0.05065559-0.31894488j]

# %%
np.stack((centres.real,centres.imag)).shape
# Out:
# (2, 59051)
